# %% [markdown]
# ## Este es un titulo 1

# %% [markdown]
# - a
# - b
# - c

# %%
var1 = 1

# %%
var2 = 43

# %%
sum = var1 + var2

# %%
sum
# Out:
# 44

# %%
if sum > 10 :
    print("true")
# Out:
# true
